# %% [markdown]
# ## Please Type your student ID and group Number:

# %% [markdown]
# # Data Preprocessing: Imputing Missing Values
# In this lab, you will practice handling missing data, an essential step in data preprocessing. The dataset below is a randomly generated DataFrame with several values intentionally replaced by NaN. You will use it to explore different imputation techniques, including:
# - Removing rows with missing values
# - Filling missing values with a constant (e.g., 0)
# - Filling missing values with statistical measures (e.g., column mean)
#
# Run the following code to create the dataset you will work with:

# %%
import numpy as np
from numpy import nan as NA 
import pandas as pd
import numpy.random as random
random.seed(0)
df2 = pd.DataFrame(np.random.rand(15, 6))
df2.iloc[2,0] = NA
df2.iloc[5:8,2] = NA 
df2.iloc[7:9,3] = NA 
df2.iloc[10,5] = NA
df2

# %% [markdown]
# ## Reference for Missing‑Value Imputation
# You may find helpful examples of how to handle and impute missing values in **1.Data Preprocessing_python-code.pptx**, slides 64-72. Review those slides if you need guidance on the techniques used in the following exercises.
#
# Please continue with Q 1–3, where you will practice:
# - Deleting rows with missing values
# - Filling missing values with a constant
# - Filling missing values using statistical measures

# %% [markdown]
# ## Q 1 Delete the row with NaN.

# %%
# TODO: Write the code to remove all rows that contain NaN values.



#Print the cleaned DataFrame

# %% [markdown]
# ## Q 2 Fill 0 for NaN

# %%
# TODO: Write the code to replace all NaN values with 0.



#Print the updated DataFrame

# %% [markdown]
# ## Q 3 Fill mean value for NaN

# %%
# TODO: Write the code to replace all NaN values with the mean of their column.



#Print the updated DataFrame
